# %% [markdown]
# # Work3: UserId, Text Getter Module

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time
#######################################################################################################################
# 셀레니움 셋업 #
#######################################################################################################################
chromedriver = 'chromedriver'           # 크롬 드라이버 상대경로로 할당 #
driver = webdriver.Chrome(chromedriver) # 할당 된 크롬 드라이버를 dirver에 할당 # 

driver.get('https://www.instagram.com/') # 인스타 주소를 driver 올려준다 #
SCROLL_PAUSE_SEC = 2
########################################################################################################################
# 로그인 #
########################################################################################################################
# 인스타 계정 Login 정보 #
username = '01073391013'
password = 'slqlrjf12#$'
# 로그인 입력 창 및 버튼 Xapth 주소 #
InEmail_id = "//*[@id='loginForm']/div/div[1]/div/label/input"
InPassword_id = "//*[@id='loginForm']/div/div[2]/div/label/input"
loginButton = "//*[@id='loginForm']/div/div[3]/button"
# Css 예시 #
#id_data = driver.find_element_by_css_selector('#loginForm > div > div:nth-child(1) > div > label > input')

# 4초간 기다린 후 각각의 로그인 필드들을 동기화 해준다 #
id_field = WebDriverWait(driver, 4).until(EC.presence_of_element_located((By.XPATH, InEmail_id))) # ID INPUT 지정 #
pw_field = WebDriverWait(driver, 4).until(EC.presence_of_element_located((By.XPATH, InPassword_id))) # 비밀번호 INPUT 지정 #
loginButton_tag = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, loginButton))) # Login 지정 #

# id, 비밀번호를 입력 후 로그인 버튼을 누른다 # 
id_field.clear() # ID 칸 비우기 #
id_field.send_keys(username) # ID 입력: ID에 담긴 데이터 전달 #
pw_field.clear() # 비밀번호 칸 비우기 #
pw_field.send_keys(password) # 비밀번호 입력: password에 담긴 데이터 전달 #
loginButton_tag.click() # 로그인 버튼 클릭 #

#######################################################################################################################
# 본격 크롤링 #
time.sleep(4)
#######################################################################################################################
# 시작 버튼 클릭 #
# 인스타 시작시에 귀찮게 구는 팝업창 없애기 위한 부분 #
startButton = "//*[@id='react-root']/section/main/div/div/div/div/button"
startButton_Key = driver.find_element_by_xpath(startButton)
startButton_Key.click() # 첫 번째 팝업 버튼 매핑 후 클릭 해주는 구문 #
time.sleep(2)
startButton2 = "/html/body/div[4]/div/div/div/div[3]/button[2]"
startButton_Key2 = driver.find_element_by_xpath(startButton2)
startButton_Key2.click() # 두 번째 팝업 버튼 매핑 후 클릭 해주는 구문 #


# v1Nh3 kIKUG  _bz0w
f = open("DefUserName.txt", 'a',encoding='UTF-8') # 파일 쓰기를 위한 f 변수 할당 #
ft = open("DefUserText.txt", 'a', encoding='UTF-8') # 파일 쓰기를 위한 f 변수 할당 #

with open("PostUrlSet.txt", 'r') as fUrlList:
    UrlList = []
    for line in fUrlList:
        UrlList.append(line)
UrlList = open("PostUrlSet.txt", 'r') # 파일 읽에서 URL 읽기 #

i = 0
# 각 게시글 접속 #
time.sleep(4)     # 더보기 버튼 Xpath 경로 저장 #
ShowMoreButton = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul/li/div"
for url in UrlList:
    time.sleep(1)
    print(url.rstrip('\n'))
    print ("location.replace(\'"+ url.rstrip('\n') +"\')")
    driver.execute_script("location.replace(\'"+ url.rstrip('\n') +"\')")
    # driver.execute_script('location.href=' + "\'" + url + "\'")
    i += 1
    time.sleep(3)
    j = 0
    time.sleep(1)
    try:
        UserList = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul"
        UserList_tag = driver.find_element_by_xpath(UserList)
        UserList_size = UserList_tag.find_elements_by_class_name('Mr508')
        length = len(UserList_size)
        a = list(range(length))
    except:
        a = list(range(1))
        pass
    
    try:
        print ('길이: ' + str(UserList_tag))
        if (length > 8 ):
            ShowMoreButton_Tag = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, ShowMoreButton)))
            while True:   # 끝까지 스크롤 다운
                if (WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, ShowMoreButton)))):
                    ShowMoreButton_Tag.click()
                time.sleep(2)
                j += 1
                if j == 8:
                    break
    except TimeoutException:
        print("버튼없어!!")
    for num, ListSizeTemp in enumerate (a):
        # UserId = "/html/body/div[5]/div[2]/div/article/div[3]/div[1]/ul/ul["+str(num+1)+"]/div/li/div/div[1]/div[2]/h3/div/span/a"
        UserId = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul/ul["+str(num+1)+"]/div/li/div/div[1]/div[2]/h3/div/span/a"
        # UserText = "/html/body/div[5]/div[2]/div/article/div[3]/div[1]/ul/ul["+str(num+1)+"]/div/li/div/div[1]/div[2]/span"
        UserText = "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul/ul["+str(num+1)+"]/div/li/div/div[1]/div[2]/span"
        # "//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/div[1]/ul/ul["+str(num+1)+"]/div/li/div/div[1]/div[2]/span"
        
        try:
            UserId_Cont = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, UserId)))
            UserText_Cont = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, UserText))) 
            data = (UserId_Cont.get_attribute('text')+"\n")
            print ('Id Data: '+ data)
            f.write(data)
            data2 = (UserText_Cont.text+"\n")
            print ('text Data: '+ data2)
            ft.write(data2)
        except:
            pass
        
    
    # driver.execute_script("window.history.go(-1)")
f.close()
ft.close()
print("완벽 정상 작동")
#driver.quit()
# Out:
# https://www.instagram.com/p/CJLLV1hHnk3/
# location.replace('https://www.instagram.com/p/CJLLV1hHnk3/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="edbc97c7-6c8f-43a1-ba96-beec9a0f289a")>
# 버튼없어!!
# Id Data: yellow2ith.me
#
# text Data: ✍
#
# Id Data: gallgil_9manlee
#
# text Data: 저는 우울증이 정말 심했을 때 창문열기가 그렇게 무섭더라구요. 제가 혹시나 뛰어내릴까봐...너무 괴로워서 자유롭고 싶어질까봐.. 큰 용기를 내서 병원에 가고, 약을 먹고 난 후엔 창문 열었을 때 불어온 시원한 바람이 제 기분을 너무 좋게 만들더라구요 우울증이란 약먹으면 낫는 그냥 감기같은건가봐요
#
# Id Data: hana__bank
#
# text Data: (눈물로 인해 탈수증 온 댓글 입니다)..누군가에겐 저 간단해 보이는 창문 열기가 작가님의 삶을 바꿔준 대단한 무언가가 된 것 같아요..🥺😭😭
#
# Id Data: lily.x.z_666
#
# text Data: ㅠㅠ진짜 너무 공감돼요. 저도 막 좋아지기 시작했을 때 나를 죄인으로 만든 것도, 내게 제일 모질게 굴었던 사람도, 나를 불쌍하게 만들었던 사람도, 나를 제일 슬프게 했던 사람도 전부 나였다는걸 알게되었어요. 그랬더니 그 괴로웠던 시간들이 허망하기도 하고, 아니기도 하고.. 좀 복잡한 감정으로 자주 울었던 것 같아요.
#
# Id Data: 0l_ll_l7
#
# text Data: 술에 취해 방 안에 엎드리곤 울음을 터뜨리며 소리 치던 제가 생각이 나요 우울할 뿐인 내용이 왜 이리 감사할까요
#
# Id Data: 4wonforone
#
# text Data: 알면서도 모른체하고 살아갔던 지난 나날들..
#
# Id Data: kka_meee
#
# text Data: 💗👍🏻
#
# Id Data: hebbang_drawing
#
# text Data: 아.. 오늘 편은 특히 마음이 더 아프네요😢
#
# Id Data: ha_glass
#
# text Data: 진짜 너무 눈물나네요...우리 힘내요!
#
# Id Data: jhssamm
#
# text Data: 진짜진짜 잘 하셨어요 보면서 진짜 행복해요✨
#
# Id Data: kyeong_yami
#
# text Data: 창문열어보기 꼭 기억해둬야겠어요💕 작가님도 행복하고 따뜻한 연말 보내세요💝
#
# Id Data: sojung_0811
#
# text Data: 열린 창문처럼 솜님의 앞으로의 일상도 활짝 열리고 행복만 가득했으면 좋겠어요👀❤
#
# https://www.instagram.com/p/CHtnOlhH7sJ/
# location.replace('https://www.instagram.com/p/CHtnOlhH7sJ/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="6dc49b2b-0fae-4c9a-98aa-2ca947e0ff9e")>
# Id Data: non.ame4442
#
# text Data: 그림 너무너무 좋아요 진짜😭
#
# Id Data: yoohwa_91
#
# text Data: 요즘 작가님 작품에서 물고기나 도롱뇽이 많이 보이는거 같아요! 무슨 의마라도 있을까욤? 😭😭
#
# Id Data: chicoltrash
#
# text Data: concrete ark with friends
#
# Id Data: nick_uvur
#
# text Data: It is really cool
#
# Id Data: parasite_03
#
# text Data: 언제나 봐도 예쁜 그림 어떻게!!!❤️❤️👏
#
# Id Data: ihyeon_gain
#
# text Data: 색감 쩌러요!! 너무 마음에 드는.. !! 핸드폰케이스로 제작되도 예쁠것같습니당
#
# https://www.instagram.com/p/CJ_VbACl6u6/
# location.replace('https://www.instagram.com/p/CJ_VbACl6u6/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="7822c3b6-0be2-45af-90db-f0678706a8b0")>
# https://www.instagram.com/p/CJ_IiZQgx09/
# location.replace('https://www.instagram.com/p/CJ_IiZQgx09/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="eeb15b33-4ccc-41f8-b620-8fed408bf0de")>
# Id Data: about_woowool
#
# text Data: ㅠㅠ..... 😢.... ㅠㅠ...표현 눈물나네요..
#
# Id Data: leemon_diary
#
# text Data: 맞말이에요ㅠㅠ ... 우울증 힘들죠..! 잘 읽고 갑니다..😢 ..
#
# https://www.instagram.com/explore/locations/
# location.replace('https://www.instagram.com/explore/locations/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="eeb15b33-4ccc-41f8-b620-8fed408bf0de")>
# https://www.instagram.com/p/CJwn9u3lfNg/
# location.replace('https://www.instagram.com/p/CJwn9u3lfNg/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="7ad8d517-66c0-4371-8bd4-6300d662cd2b")>
# 버튼없어!!
# Id Data: jaehong_92growup
#
# text Data: 몇 달간 바뀌지 않았던 마음 습관을 '자기 연민'으로 바꿔 실천해 봅니다.😄
#
# Id Data: jaehong_92growup
#
# text Data: 자기비판 수치심 어찌보면 내가 힘든 일 겪고 난 뒤 느껴야만 한다 생각했던 감정이 나를 좀 먹고 있었다는 것.
#
# Id Data: beast_mind_korea
#
# text Data: 자기비판을 자기연민으로 바꿔야겠군요👏
#
# Id Data: im_mijung_80
#
# text Data: 퍼가요~👍👍🙏🙏🙏😍😍
#
# Id Data: gksmgksm96
#
# text Data: 스스로 자비하면 더 망하던데 나만 그런가요?
#
# Id Data: mingyuchoi3
#
# text Data: 따뜻한 마음가짐의 필요성⏰💙
#
# Id Data: bestlife77777
#
# text Data: 서론이 왤캐길어;;
#
# Id Data: sungwoo9_
#
# text Data: 자기연민, 위로를 바라는 마음 이런 것들도 우울증만큼은 아니지만 마음을 좀먹는 애들입니다. 우울증이 있는 분들을 위한 극약치료제정도는 될지 모르지만 그 자체로 좋은 건 아닙니다.
#
# Id Data: dreamerum89
#
# text Data: 내 자신을 부끄럽게 여기지 않으려 하지만 주변에서 짐으로 여기거나 수치스럽게 또는 부끄럽게 여기는 경우가 많아서 자꾸 위축되네요.
#
# Id Data: __nrz5__
#
# text Data: @aezielove
#
# Id Data: study_melancholy
#
# text Data: @surfin_vxx0420 나구나
#
# Id Data: ja__min_
#
# text Data: @ey____n.n 그렇대!!!!!
#
# https://www.instagram.com/p/CJ_KGkzhmpy/
# location.replace('https://www.instagram.com/p/CJ_KGkzhmpy/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="9af768b4-8cd7-488e-9dac-07a25e0f23a7")>
# Id Data: lv4_silent_nova
#
# text Data: 오늘 괴로우셨겠군요.😭 오늘 같은 날은 어쩔 수 없죠 술 한잔이 위로가 되신다면 그것도 괜찮아요😭 너무 많이 드시지 마세요. 파랑님은 소중한 존재니깐요.❤️절대 구경거리가 아니예요. 같잋마셔 드리고 싶어 지네요. 괴로움을 나누고 싶어요.♥
#
# Id Data: lsy._.tr
#
# text Data: 오늘 하루도 너무 고생하셨습니다!! 🙏 혼자 우울에 빠지지 마시고 나누어요 ㅠㅠ ❤️
#
# Id Data: chestnut_bami
#
# text Data: 어디 얘기 해봤자 안타까울 구경거리라는 표현 정말 너어무 찰떡이에요...😢 하 진짜 제가 하고 싶은 말을 너어어어어무 잘 표현해주셔서 속시원하구 위로되구 그러네요🙏🏻💛
#
# https://www.instagram.com/p/CJ_EvgfjyTT/
# location.replace('https://www.instagram.com/p/CJ_EvgfjyTT/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="90cf5e5b-2a44-4e07-8eee-2ceef6e543e1")>
# Id Data: u__y3on
#
# text Data: 당신의 한 손엔 사랑하는 사람의 손이! 나머지 한 손에는 회 한 접시가 들려있을거에요💙🐟
#
# https://www.instagram.com/p/CJ_CLsphpw6/
# location.replace('https://www.instagram.com/p/CJ_CLsphpw6/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="28dd310d-a79b-41ca-9479-8ff4529d31a8")>
# Id Data: zigum.record
#
# text Data: ❤️
#
# https://www.instagram.com/p/CJ_R77SHRvC/
# location.replace('https://www.instagram.com/p/CJ_R77SHRvC/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="67d1d99f-8b8d-453c-9420-6a0ffcb21aef")>
# https://www.instagram.com/explore/
# location.replace('https://www.instagram.com/explore/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="67d1d99f-8b8d-453c-9420-6a0ffcb21aef")>
# https://www.instagram.com/legal/privacy/
# location.replace('https://www.instagram.com/legal/privacy/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="67d1d99f-8b8d-453c-9420-6a0ffcb21aef")>
# https://www.instagram.com/p/CJ-_7hDF8TJ/
# location.replace('https://www.instagram.com/p/CJ-_7hDF8TJ/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="51d529c6-66c7-4a58-9826-9c93f7347dc2")>
# https://www.instagram.com/p/CJ_ORn7H7Pv/
# location.replace('https://www.instagram.com/p/CJ_ORn7H7Pv/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="c156829a-fd99-4dd1-bcb1-a0c997e1c875")>
# Id Data: 0d8_interior
#
# text Data: 헐....
#
# Id Data: seyeongp3842
#
# text Data: 하.. 다 포기다 그냥..ㅠㅠㅋㅋ
#
# Id Data: seovely.s2
#
# text Data: 다비이인.. 화이띵 ㅜㅜ
#
# Id Data: yyyyyoung___
#
# text Data: 🤯🤯🤯🤯
#
# Id Data: by___e__
#
# text Data: 유에스비에 없더나
#
# Id Data: b2nee
#
# text Data: 🤦‍♂️
#
# Id Data: seyeongp3842
#
# text Data: 하.. 다 포기다 그냥..ㅠㅠㅋㅋ
#
# Id Data: wulzzuk_hulzzuk
#
# text Data: 😢
#
# https://www.instagram.com/p/CJ_CFHMFiNn/
# location.replace('https://www.instagram.com/p/CJ_CFHMFiNn/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="b40f1d59-93f8-4fd5-a67e-d0cf112c797a")>
# https://www.instagram.com/p/CJ_Nw72B4z_/
# location.replace('https://www.instagram.com/p/CJ_Nw72B4z_/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="2a322e96-3d1e-44ba-847e-8057e90d638f")>
# https://www.instagram.com/p/CJ_Bte0guv0/
# location.replace('https://www.instagram.com/p/CJ_Bte0guv0/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="5d759ecf-6f56-422b-9682-30da59805b8f")>
# Id Data: 2021_01_13_
#
# text Data: #いいぞいいぞ #いいぞみんなフォロー #よい #自撮り #韓国
# #좋아요 #좋반 #좋아요반사 #좋아요테러 #인친 #좋반 #좋아요반사 #좋아요테러 #우울증 #우울공감소 #우울글귀 #행복
#
# https://www.instagram.com/about/jobs/
# location.replace('https://www.instagram.com/about/jobs/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="5d759ecf-6f56-422b-9682-30da59805b8f")>
# https://www.instagram.com/legal/terms/
# location.replace('https://www.instagram.com/legal/terms/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="5d759ecf-6f56-422b-9682-30da59805b8f")>
# https://www.instagram.com/developer/
# location.replace('https://www.instagram.com/developer/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="5d759ecf-6f56-422b-9682-30da59805b8f")>
# https://www.instagram.com/p/CJ5iG-rHwKM/
# location.replace('https://www.instagram.com/p/CJ5iG-rHwKM/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="2d6bad93-9efb-4f28-8f34-e0181e80b1e1")>
# 버튼없어!!
# Id Data: gung_daeng_mom
#
# text Data: ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ이 편은 눈물수도꼭지 ㅠㅠㅠㅠㅠㅠㅠ
#
# Id Data: yellow2ith.me
#
# text Data: ✍
#
# Id Data: hello_cokey
#
# text Data: 암요 부모님께는 누가 뭐래도 금쪽같은 자식이지요 전에도 달았지만 지나간 일들이라 다행이에요. 그리고 아직 터널속인 분들께도 응원을 보냅니다.
#
# Id Data: h_ju_vi0
#
# text Data: 울지 않으려고 했는데 마지막 가족사진 그림을 보고 소리없이 주르륵 흘러나왔어요 제 주위에도 소중한 사람이 있다는 것을 다시 한번 생각하게 해주셔서 감사합니다💛
#
# Id Data: youth_ol
#
# text Data: 작가님이 무슨 마음으로 공들이고 싶어하셨는지 조금은 알 것 같아요. 심장이 덜컥할 만큼 아픈 화였어요.. 작가님 곁에 어머니가 있어주셔서, 우리가 지금 이렇게 작가님을 볼 수 있어서 다행이에요.
#
# Id Data: hana__bank
#
# text Data: 아니 그.저기 휴지 남는거 있나요..
#
# Id Data: formymymy9
#
# text Data: 이해해주시는 가족분들이 있기에 얼마나 감사한지 😢 저는 외롭게 투병중이거든요 .. 식구들이 제 상황을 부인하고 제 의지탓만해서 많이 힘드네요 ㅎㅎ 그래도 솜님 피드보면서 힘내봅니다🙌
#
# Id Data: sae_neok
#
# text Data: 자해했을때 엄마가 자해한거 알면서도 무표정으로 약발라주셨던게 떠오르네요...ㅠ
#
# Id Data: ppppppppppong
#
# text Data: 꾸힝😭 넘 눈물나요😭😭😭
#
# Id Data: qqkrwl_
#
# text Data: 소중한 작가님😢💛💛
#
# Id Data: song_y.s
#
# text Data: 😢💛
#
# Id Data: k.c_kim_
#
# text Data: 왼팔에 무슨 일 있으셨나요??... 몰라서요..
#
# https://www.instagram.com/p/CJ89kRKFhPH/
# location.replace('https://www.instagram.com/p/CJ89kRKFhPH/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="71360e93-da33-4dbd-a454-881cf351e4bd")>
# https://www.instagram.com/p/CJ_UXEjBGEW/
# location.replace('https://www.instagram.com/p/CJ_UXEjBGEW/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="3b73267a-04e4-414c-a7ea-b074327e9e21")>
# https://www.instagram.com/p/CJ_RDQcFuOh/
# location.replace('https://www.instagram.com/p/CJ_RDQcFuOh/')
# 길이: <selenium.webdriver.remote.webelement.WebElement (session="6e98dcba83663600d3ee0e309f47ba44", element="3b73267a-04e4-414c-a7ea-b074327e9e21")>
# https://www.instagram.com/p/CJ-Obcbln71/
# location.replace('https://www.instagram.com/p/CJ-Obcbln71/')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-27-edc317d134ca> in <module>
#      72     print(url.rstrip('\n'))
#      73     print ("location.replace(\'"+ url.rstrip('\n') +"\')")
# ---> 74     driver.execute_script("location.replace(\'"+ url.rstrip('\n') +"\')")
#      75     # driver.execute_script('location.href=' + "\'" + url + "\'")
#      76     i += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=87.0.4280.141)
